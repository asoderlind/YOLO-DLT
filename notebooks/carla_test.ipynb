# %%
import random
import glob
import os
from PIL import Image

from utils import draw_yolo_bboxes

dataset_path = "/home/phoawb/repos/yolo-testing/datasets/carla-yolo"

cls2id = {
    'car': 0,
    'truck': 1,
    'van': 2,
    'bus': 3,
    'motorcycle': 4,
    'bicycle': 5,
}

id2cls = {
    0: 'car',
    1: 'truck',
    2: 'van',
    3: 'bus',
    4: 'motorcycle',
    5: 'bicycle',
}

# Example usage
img_path = random.sample(glob.glob(f"{dataset_path}/images/*.png"), 1)[0]
image_name = os.path.basename(img_path)[:-4]
label_path = f"{dataset_path}/labels//{image_name}.txt"

# get image width and height with PIL

img = Image.open(img_path)
width = img.size[0]
height = img.size[1]

print(img_path, label_path)
draw_yolo_bboxes(img_path, label_path, width, height, id2cls=id2cls,text_size=0.5, text_thickness=2)
# Out:
# /home/phoawb/repos/yolo-testing/datasets/carla-yolo/images/vid_1743239587_frame_000029.png /home/phoawb/repos/yolo-testing/datasets/carla-yolo/labels//vid_1743239587_frame_000029.txt
