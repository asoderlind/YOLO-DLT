# %% [markdown]
# # Let's get some statistics from the night_Canada set

# %%
country = "Australia" # change this later

dataset_path = f"../../yolo-testing/datasets/night_{country}"
train_images_path = f"{dataset_path}/train/Images"
val_images_path = f"{dataset_path}/val/Images"
test_images_path = f"{dataset_path}/test/Images"

bg_train_images_path = f"{dataset_path}/background/train"
bg_val_images_path = f"{dataset_path}/background/val"
bg_test_images_path = f"{dataset_path}/background/test"

# %%
import glob

train_images_list = glob.glob(f"{train_images_path}/*.jpg")
train_images_list_len = len(train_images_list)

# Get lists of images
train_images_list = glob.glob(f"{train_images_path}/*.jpg")
val_images_list = glob.glob(f"{val_images_path}/*.jpg")
test_images_list = glob.glob(f"{test_images_path}/*.jpg")

# Get lists of background images
bg_train_images_list = glob.glob(f"{bg_train_images_path}/*.jpg")
bg_val_images_list = glob.glob(f"{bg_val_images_path}/*.jpg")
bg_test_images_list = glob.glob(f"{bg_test_images_path}/*.jpg")

# Get lengths
train_images_list_len = len(train_images_list)
val_images_list_len = len(val_images_list)
test_images_list_len = len(test_images_list)

bg_train_images_list_len = len(bg_train_images_list)
bg_val_images_list_len = len(bg_val_images_list)
bg_test_images_list_len = len(bg_test_images_list)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ('Training Set', 'Test Set', 'Validation Set')
daytime_distribution = {
    "labeled": (train_images_list_len, test_images_list_len, val_images_list_len),
    "background": (bg_train_images_list_len, bg_test_images_list_len, bg_val_images_list_len)
}

# Bar width and positions
base_offset = 0.1715
bar_width = 0.33
x = np.arange(len(categories))
multiplier = 0

# Create stacked bar chart
fig, ax = plt.subplots()
for time, number in daytime_distribution.items():
    offset = bar_width * multiplier
    rects = ax.bar(base_offset + x + offset, number, bar_width, label=time)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Labels and title
ax.set_ylabel('Number of occurences')
ax.set_title(f'night_{country} images by background or labeled')
ax.set_xticks(x + bar_width, categories)
ax.legend(loc="upper right", ncols=2)
ax.set_ylim(0, 40000)


# Show plot
plt.show()

# %%
# label classes
with open (f"{dataset_path}/label_class.txt") as f:
    id2cls = dict()
    lines = f.readlines()
    for line in lines:
        cid, c = line.split(',')
        cid = int(cid)
        id2cls[cid] = c.strip()
print(id2cls)
# Out:
# {1: 'vehicle', 2: 'person', 3: 'bus', 4: 'minibus', 5: 'truck', 6: 'traffic_sign'}

# %% [markdown]
# ## create labels folder in night_{country}

# %%
import os

labels_folder_path = f"{dataset_path}/labels"
os.makedirs(labels_folder_path, exist_ok=True)

train_labels_folder_path = labels_folder_path + "/train"
os.makedirs(train_labels_folder_path, exist_ok=True)

val_labels_folder_path = labels_folder_path + "/val"
os.makedirs(val_labels_folder_path, exist_ok=True)

test_labels_folder_path = labels_folder_path + "/test"
os.makedirs(test_labels_folder_path, exist_ok=True)

# %% [markdown]
# ## Parse the json label files

# %% [markdown]
# images: [{
#     file_name: string
#     id: number
#     width: number
#     height: number
# }],
#
# annotations: list[{
#     id: number
#     image_id: number
#     category_id: number
#     segmentation: []
#     area: number
#     bbox: [num,num,num,num]
#     iscrowd: number
#
# }]

# %%
import json
from tqdm import tqdm

def coco_to_yolo(coco_bbox, img_width, img_height):
    x_min, y_min, width, height = coco_bbox
    # Convert to YOLO format (normalized)
    x_center = (x_min + (width / 2)) / img_width
    y_center = (y_min + (height / 2)) / img_height
    width = width / img_width
    height = height / img_height
    return (x_center, y_center, width, height)


def create_txt_labels(json_file, labels_folder, save=True):
    with open(json_file, 'r') as f:
        data = json.load(f)
    images = data["images"]
    print(f"{len(images)} images in total in {json_file}")
    annotations = data["annotations"]
    for image in tqdm(images):
        image_id = image["id"]
        name = image["file_name"]
        out_file = labels_folder + name[:-3] + "txt"
        img_width, img_height = image["width"], image["height"]
        matching_annotations = [a for a in annotations if a["image_id"] == image_id]

        img_annotations = list()
        for annotation in matching_annotations:
            x_c, y_c, w, h = coco_to_yolo(annotation["bbox"], img_width, img_height)
            cat_id = annotation["category_id"]
            img_annotations.append(f"{cat_id} {x_c:.6f} {y_c:.6f} {w:.6f} {h:.6f}")
            
        if (save):
            with open(out_file, "w") as f:
                f.writelines('\n'.join(img_annotations))

# obj training labels
create_txt_labels(f"{dataset_path}/train/train.json", f"{labels_folder_path}/train/")
create_txt_labels(f"{dataset_path}/val/val.json", f"{labels_folder_path}/val/")
create_txt_labels(f"{dataset_path}/test/test.json", f"{labels_folder_path}/test/")
# Out:
# 3923 images in total in ../../yolo-testing/datasets/night_Australia/train/train.json
# 100%|██████████| 3923/3923 [00:01<00:00, 3115.24it/s]
# 1308 images in total in ../../yolo-testing/datasets/night_Australia/val/val.json
# 100%|██████████| 1308/1308 [00:00<00:00, 6099.84it/s]
# 1308 images in total in ../../yolo-testing/datasets/night_Australia/test/test.json
# 100%|██████████| 1308/1308 [00:00<00:00, 5979.84it/s]

# %% [markdown]
# # Create Images folder

# %%
images_folder_path = f"{dataset_path}/images"
os.makedirs(images_folder_path, exist_ok=True)

train_images_folder_path = images_folder_path + "/train"
os.makedirs(train_images_folder_path, exist_ok=True)

val_images_folder_path = images_folder_path + "/val"
os.makedirs(val_images_folder_path, exist_ok=True)

test_images_folder_path = images_folder_path + "/test"
os.makedirs(test_images_folder_path, exist_ok=True)

# %% [markdown]
# # Move object images to images folder

# %%
import shutil
import glob

sources = [f"{dataset_path}/test/Images", f"{dataset_path}/train/Images", f"{dataset_path}/val/Images"]
destinations = [f"{dataset_path}/images/test", f"{dataset_path}/images/train", f"{dataset_path}/images/val"]

for source, dest in zip(sources, destinations):
    print(f"Moving from {source} to {dest}")
    files = glob.glob(f"{source}/*.jpg")
    print(f"{len(files)} files in total")
    for file in files:
        shutil.move(file, dest)
        # print(f"Moving {file} to {dest}")
# Out:
# Moving from ../../yolo-testing/datasets/night_Australia/test/Images to ../../yolo-testing/datasets/night_Australia/images/test
# 1308 files in total
# Moving from ../../yolo-testing/datasets/night_Australia/train/Images to ../../yolo-testing/datasets/night_Australia/images/train
# 3923 files in total
# Moving from ../../yolo-testing/datasets/night_Australia/val/Images to ../../yolo-testing/datasets/night_Australia/images/val
# 1308 files in total

# %% [markdown]
# # Sanity check

# %%
# Check that all images were moved from their original location
assert(len(os.listdir(sources[0])) == 0)
assert(len(os.listdir(sources[1])) == 0)
assert(len(os.listdir(sources[2])) == 0)

# Check that the number of images and labels are the same
len_train_images = len(glob.glob(f"{dataset_path}/images/train/*.jpg"))
len_val_images = len(glob.glob(f"{dataset_path}/images/val/*.jpg"))
len_test_images = len(glob.glob(f"{dataset_path}/images/test/*.jpg"))

len_train_labels = len(glob.glob(f"{dataset_path}/labels/train/*.txt"))
len_val_labels = len(glob.glob(f"{dataset_path}/labels/val/*.txt"))
len_test_labels = len(glob.glob(f"{dataset_path}/labels/test/*.txt"))

print(f"Images: train {len_train_images}, test {len_test_images}, val {len_val_images}")
print(f"Labels: train {len_train_labels}, test {len_test_labels}, val {len_val_labels}")
# Out:
# Images: train 3923, test 1308, val 1308
# Labels: train 3923, test 1308, val 1308

# %% [markdown]
# # Background image processing

# %%
import random 

train_background_images = glob.glob(f"{dataset_path}/background/train/*.jpg")
test_background_images = glob.glob(f"{dataset_path}/background/test/*.jpg")
val_background_images = glob.glob(f"{dataset_path}/background/val/*.jpg")

print(f"Total background train images: {len(train_background_images)}")
print(f"Total background test images: {len(test_background_images)}")
print(f"Total background val images: {len(val_background_images)}")

selected_train_background_images = random.sample(train_background_images, len(train_background_images) // 10)
selected_test_background_images = random.sample(test_background_images, len(test_background_images) // 10)
selected_val_background_images = random.sample(val_background_images, len(val_background_images) // 10)

print(f"Total selected train bg images: {len(selected_train_background_images)}")
print(f"Total selected test bg images: {len(selected_test_background_images)}")
print(f"Total selected val bg images: {len(selected_val_background_images)}")
# Out:
# Total background train images: 27390
# Total background test images: 11798
# Total background val images: 11798
# Total selected train bg images: 2739
# Total selected test bg images: 1179
# Total selected val bg images: 1179

# %%
from pathlib import Path

def process_bg_images(file_list, label_output_dir, image_output_dir):
    for filename in file_list:
        image_name = os.path.basename(filename)[:-4]
        label_file = f"{label_output_dir}/{image_name}.txt"

        # create empty label txt file
        if (not os.path.isfile(label_file)):
            Path(label_file).touch()

        # move image to output dir
        if (os.path.isfile(filename)):
            shutil.move(filename, image_output_dir)

process_bg_images(selected_train_background_images, f"{dataset_path}/labels/train", f"{dataset_path}/images/train")
process_bg_images(selected_test_background_images, f"{dataset_path}/labels/test", f"{dataset_path}/images/test")
process_bg_images(selected_val_background_images, f"{dataset_path}/labels/val", f"{dataset_path}/images/val")

# %%
# Check that the number of images and labels are the same
len_train_images = len(glob.glob(f"{dataset_path}/images/train/*.jpg"))
len_val_images = len(glob.glob(f"{dataset_path}/images/val/*.jpg"))
len_test_images = len(glob.glob(f"{dataset_path}/images/test/*.jpg"))

len_train_labels = len(glob.glob(f"{dataset_path}/labels/train/*.txt"))
len_val_labels = len(glob.glob(f"{dataset_path}/labels/val/*.txt"))
len_test_labels = len(glob.glob(f"{dataset_path}/labels/test/*.txt"))

print(f"Images: train {len_train_images}, test {len_test_images}, val {len_val_images}")
print(f"Labels: train {len_train_labels}, test {len_test_labels}, val {len_val_labels}")
# Out:
# Images: train 8209, test 2487, val 2487
# Labels: train 8209, test 2487, val 2487

# %%
# Count number of background training images by way of empty label files
count = 0
background_labels = []
for label in glob.glob(f"{dataset_path}/labels/train/*.txt"):
    if (os.path.getsize(label) == 0):
        count += 1
        background_labels.append(label)
print(f"Number of background training images: {count}")
print(f"Number of foreground training images: {len_train_images - count}")

# Remove 60% of the background training images
if (len(background_labels) > 10000):
    random.shuffle(background_labels)
    remove_count = int(len(background_labels) * 0.6)
    remove_files = background_labels[:remove_count]
    for label_file in remove_files:
        filename = label_file[:-4] + ".jpg"
        filename = filename.replace("labels", "images")
        print(f"Removing {label_file} and {filename}")
        os.remove(label_file)
        os.remove(filename)
# Out:
# Number of background training images: 10758
# Number of foreground training images: 3905
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234728F_1623.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234728F_1623.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222128F_459.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222128F_459.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223633F_1368.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223633F_1368.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_825.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_825.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231846F_1614.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231846F_1614.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_54.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_54.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-215621F_1521.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-215621F_1521.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223432F_1077.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223432F_1077.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002035F_1044.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002035F_1044.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223332F_486.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223332F_486.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233250F_1668.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233250F_1668.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224937F_1467.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224937F_1467.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221927F_378.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221927F_378.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231022F_948.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231022F_948.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230421F_1641.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230421F_1641.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230822F_1446.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230822F_1446.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221727F_1725.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221727F_1725.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001436F_1674.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001436F_1674.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_1425.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_1425.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230822F_1491.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230822F_1491.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232046F_1362.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232046F_1362.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234828F_789.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234828F_789.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224937F_1617.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224937F_1617.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223633F_1062.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223633F_1062.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235630F_630.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235630F_630.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221927F_1341.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221927F_1341.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220423F_354.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220423F_354.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233852F_1272.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233852F_1272.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232949F_1533.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232949F_1533.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_168.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_168.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230542F_321.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230542F_321.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-212712F_1182.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-212712F_1182.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224636F_1182.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224636F_1182.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220824F_69.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220824F_69.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231846F_264.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231846F_264.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233952F_1614.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233952F_1614.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_1533.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_1533.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214517F_1686.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214517F_1686.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002035F_408.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002035F_408.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232447F_1605.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232447F_1605.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-235156F_1539.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-235156F_1539.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_117.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_117.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231344F_390.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231344F_390.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225037F_312.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225037F_312.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223733F_1341.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223733F_1341.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225037F_33.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225037F_33.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233651F_864.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233651F_864.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234828F_1581.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234828F_1581.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230441F_618.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230441F_618.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-234855F_1407.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-234855F_1407.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230721F_1530.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230721F_1530.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222128F_681.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222128F_681.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235028F_1761.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235028F_1761.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222329F_1677.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222329F_1677.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223232F_675.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223232F_675.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231123F_1053.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231123F_1053.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233751F_1575.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233751F_1575.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235530F_387.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235530F_387.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230922F_375.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230922F_375.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001235F_1002.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001235F_1002.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221627F_1668.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221627F_1668.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_69.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_69.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225438F_414.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225438F_414.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214317F_981.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214317F_981.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-225417F_984.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-225417F_984.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233551F_501.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233551F_501.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232046F_1005.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232046F_1005.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230943F_855.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230943F_855.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_1380.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_1380.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222028F_1335.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222028F_1335.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_447.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_447.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222730F_1419.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222730F_1419.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233651F_1011.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233651F_1011.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224636F_711.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224636F_711.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224235F_1467.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224235F_1467.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234828F_1590.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234828F_1590.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001035F_1140.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001035F_1140.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230542F_777.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230542F_777.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234326F_1227.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234326F_1227.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_1542.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_1542.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220323F_1197.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220323F_1197.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220423F_1284.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220423F_1284.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232046F_1698.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232046F_1698.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224235F_894.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224235F_894.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001135F_180.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001135F_180.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231444F_390.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231444F_390.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221827F_1074.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221827F_1074.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223733F_648.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223733F_648.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221627F_180.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221627F_180.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233250F_1041.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233250F_1041.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220222F_444.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220222F_444.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231043F_1647.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231043F_1647.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233651F_831.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233651F_831.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_1770.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_1770.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_897.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_897.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230922F_705.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230922F_705.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234326F_564.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234326F_564.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225538F_1443.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225538F_1443.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232548F_1041.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232548F_1041.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232247F_567.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232247F_567.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001235F_924.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001235F_924.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000332F_75.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000332F_75.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220924F_1632.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220924F_1632.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_1278.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_1278.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231143F_834.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231143F_834.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000132F_213.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000132F_213.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225438F_363.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225438F_363.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_21.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_21.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225338F_1044.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225338F_1044.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223232F_1752.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223232F_1752.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221526F_678.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221526F_678.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224937F_1503.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224937F_1503.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000433F_1770.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000433F_1770.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232648F_87.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232648F_87.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232447F_243.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232447F_243.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231444F_1743.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231444F_1743.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231043F_141.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231043F_141.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224836F_1023.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224836F_1023.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232046F_1581.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232046F_1581.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232748F_630.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232748F_630.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223833F_336.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223833F_336.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231244F_1527.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231244F_1527.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231745F_309.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231745F_309.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233049F_1035.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233049F_1035.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223532F_348.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223532F_348.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230822F_1131.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230822F_1131.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_453.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_453.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223733F_1521.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223733F_1521.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_1650.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_1650.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_1128.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_1128.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223332F_753.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223332F_753.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230742F_111.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230742F_111.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221025F_582.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221025F_582.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231244F_828.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231244F_828.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231645F_408.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231645F_408.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-215520F_741.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-215520F_741.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-234153F_711.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-234153F_711.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220423F_12.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220423F_12.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224034F_282.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224034F_282.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223733F_1098.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223733F_1098.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231143F_969.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231143F_969.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220724F_1395.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220724F_1395.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000433F_1689.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000433F_1689.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233852F_1722.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233852F_1722.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224435F_594.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224435F_594.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225338F_60.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225338F_60.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_1596.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_1596.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231022F_1092.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231022F_1092.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235129F_345.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235129F_345.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222128F_165.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222128F_165.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232347F_1215.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232347F_1215.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224937F_1044.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224937F_1044.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230542F_69.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230542F_69.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214417F_588.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214417F_588.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214417F_552.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214417F_552.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223532F_414.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223532F_414.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230441F_258.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230441F_258.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001135F_999.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001135F_999.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230742F_1323.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230742F_1323.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221426F_687.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221426F_687.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231846F_1710.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231846F_1710.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231946F_1482.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231946F_1482.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_129.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_129.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223833F_630.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223833F_630.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233250F_1167.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233250F_1167.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225839F_201.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225839F_201.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221225F_267.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221225F_267.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233350F_1110.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233350F_1110.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234326F_288.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234326F_288.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232949F_318.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232949F_318.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224034F_672.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224034F_672.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000533F_627.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000533F_627.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_1002.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_1002.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231244F_1128.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231244F_1128.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224535F_936.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224535F_936.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225739F_1218.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225739F_1218.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233450F_1359.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233450F_1359.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224435F_1707.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224435F_1707.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230822F_534.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230822F_534.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224535F_1182.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224535F_1182.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223833F_507.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223833F_507.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223633F_354.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223633F_354.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222730F_1413.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222730F_1413.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_573.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_573.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231545F_504.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231545F_504.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234326F_1398.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234326F_1398.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001035F_1116.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001035F_1116.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222830F_354.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222830F_354.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230822F_1428.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230822F_1428.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_213.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_213.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225037F_1434.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225037F_1434.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224134F_1536.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224134F_1536.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224736F_456.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224736F_456.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230642F_216.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230642F_216.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-234253F_582.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-234253F_582.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233250F_1191.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233250F_1191.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002438F_1434.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002438F_1434.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223031F_369.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223031F_369.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224636F_1515.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224636F_1515.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233350F_888.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233350F_888.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_1581.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_1581.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214417F_246.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214417F_246.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221426F_522.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221426F_522.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230542F_774.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230542F_774.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001436F_780.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001436F_780.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225438F_1656.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225438F_1656.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220824F_576.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220824F_576.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232247F_1767.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232247F_1767.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233651F_309.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233651F_309.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-225117F_801.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-225117F_801.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232849F_102.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232849F_102.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-215621F_216.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-215621F_216.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220824F_597.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220824F_597.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214517F_1386.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214517F_1386.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221727F_1089.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221727F_1089.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231645F_1134.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231645F_1134.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220724F_1125.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220724F_1125.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222228F_921.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222228F_921.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_846.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_846.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231444F_279.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231444F_279.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235129F_1206.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235129F_1206.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002137F_210.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002137F_210.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231022F_1008.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231022F_1008.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225137F_1461.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225137F_1461.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230542F_738.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230542F_738.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232447F_1050.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232447F_1050.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224235F_1485.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224235F_1485.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000533F_480.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000533F_480.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231846F_1683.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231846F_1683.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002035F_87.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002035F_87.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232548F_1629.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232548F_1629.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002137F_195.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002137F_195.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221627F_690.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221627F_690.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-214617F_1659.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-214617F_1659.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221225F_1398.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221225F_1398.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222830F_69.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222830F_69.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230742F_1332.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230742F_1332.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220623F_201.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220623F_201.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233049F_1146.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233049F_1146.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230943F_492.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230943F_492.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-234855F_1347.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-234855F_1347.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221526F_645.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221526F_645.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221827F_897.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221827F_897.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_1530.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_1530.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220924F_954.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220924F_954.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-215119F_357.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-215119F_357.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_174.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_174.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-224816F_117.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-224816F_117.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-234654F_924.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-234654F_924.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222931F_243.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222931F_243.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221927F_858.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221927F_858.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234828F_1638.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234828F_1638.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223633F_9.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223633F_9.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_738.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_738.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233952F_492.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233952F_492.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230742F_1377.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230742F_1377.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235931F_1176.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235931F_1176.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222228F_1743.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222228F_1743.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225639F_1368.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225639F_1368.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224937F_687.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224937F_687.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222028F_1320.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222028F_1320.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233049F_1032.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233049F_1032.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222028F_1419.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222028F_1419.jpg
# ...
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225137F_1236.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225137F_1236.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221927F_603.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221927F_603.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223532F_195.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223532F_195.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001436F_663.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001436F_663.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220423F_264.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220423F_264.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231645F_1692.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231645F_1692.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232447F_951.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232447F_951.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235931F_1290.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235931F_1290.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233250F_1113.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233250F_1113.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221827F_213.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221827F_213.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_234.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_234.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225438F_354.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225438F_354.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220323F_615.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220323F_615.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230120F_657.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230120F_657.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223733F_1659.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223733F_1659.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234728F_216.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234728F_216.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-235931F_1296.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-235931F_1296.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000934F_672.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000934F_672.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232548F_1560.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232548F_1560.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225739F_330.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225739F_330.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231123F_288.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231123F_288.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233450F_840.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233450F_840.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223332F_78.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223332F_78.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232849F_1572.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232849F_1572.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221727F_678.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221727F_678.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225438F_918.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225438F_918.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230441F_879.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230441F_879.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221225F_219.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221225F_219.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230642F_330.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230642F_330.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225538F_276.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225538F_276.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200323-234326F_528.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200323-234326F_528.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_699.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_699.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222429F_621.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222429F_621.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-000433F_1332.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-000433F_1332.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232046F_1572.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232046F_1572.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223332F_468.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223332F_468.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222028F_936.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222028F_936.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223833F_1116.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223833F_1116.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233350F_1578.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233350F_1578.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-002337F_69.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-002337F_69.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220623F_741.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220623F_741.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224335F_3.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224335F_3.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224335F_702.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224335F_702.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224134F_471.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224134F_471.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233551F_924.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233551F_924.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232849F_1533.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232849F_1533.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224335F_822.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224335F_822.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231123F_1233.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231123F_1233.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221426F_648.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221426F_648.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224535F_1023.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224535F_1023.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225238F_93.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225238F_93.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_381.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_381.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223934F_1749.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223934F_1749.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220724F_537.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220724F_537.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224335F_264.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224335F_264.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231645F_405.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231645F_405.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222228F_816.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222228F_816.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222630F_1587.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222630F_1587.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222529F_162.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222529F_162.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225137F_993.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225137F_993.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231444F_1386.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231444F_1386.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-213113F_627.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-213113F_627.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-001135F_852.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-001135F_852.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230441F_1083.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230441F_1083.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223833F_165.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223833F_165.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233852F_306.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233852F_306.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-230922F_246.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-230922F_246.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220824F_1197.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220824F_1197.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220924F_1278.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220924F_1278.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231043F_1428.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231043F_1428.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-222228F_582.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-222228F_582.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231043F_1557.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231043F_1557.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223332F_1671.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223332F_1671.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-230943F_891.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-230943F_891.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-223131F_1419.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-223131F_1419.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220222F_489.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220222F_489.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-231344F_180.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-231344F_180.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224134F_36.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224134F_36.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-215420F_1101.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-215420F_1101.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-221526F_1764.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-221526F_1764.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-225940F_1062.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-225940F_1062.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-220824F_75.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-220824F_75.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200315-231123F_720.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200315-231123F_720.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233450F_1068.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233450F_1068.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-233852F_465.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-233852F_465.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232949F_1098.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232949F_1098.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-224636F_1236.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-224636F_1236.jpg
# Removing ../../yolo-testing/datasets/night_Australia/labels/train/FILE200324-232146F_228.txt and ../../yolo-testing/datasets/night_Australia/images/train/FILE200324-232146F_228.jpg

# %% [markdown]
# # Visualize number of background and foreground images

# %%
import matplotlib.pyplot as plt
import numpy as np

len_train_images = len(glob.glob(f"{dataset_path}/images/train/*.jpg"))
print(f"Number of training images: {len_train_images}")
len_val_images = len(glob.glob(f"{dataset_path}/images/val/*.jpg"))
print(f"Number of validation images: {len_val_images}")

# Count number of background training images by way of empty label files
background_train_count = 0
foreground_train_count = 0
for label in glob.glob(f"{dataset_path}/labels/train/*.txt"):
    if (os.path.getsize(label) == 0):
        background_train_count += 1
    else:
        foreground_train_count += 1

background_val_count = 0 
foreground_val_count = 0
for label in glob.glob(f"{dataset_path}/labels/val/*.txt"):
    if (os.path.getsize(label) == 0):
        background_val_count += 1
    else:
        foreground_val_count += 1


# Data
categories = ('Training Set', 'Validation Set')
daytime_distribution = {
    "labeled": (foreground_train_count, foreground_val_count),
    "background": (background_train_count, background_val_count)
}

# Bar width and positions
base_offset = 0.1715
bar_width = 0.33
x = np.arange(len(categories))
multiplier = 0

# Create stacked bar chart
fig, ax = plt.subplots()
for time, number in daytime_distribution.items():
    offset = bar_width * multiplier
    rects = ax.bar(base_offset + x + offset, number, bar_width, label=time)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Labels and title
ax.set_ylabel('Number of occurences')
ax.set_title(f'night_{country} images by background or labeled')
ax.set_xticks(x + bar_width, categories)
ax.legend(loc="upper right", ncols=2)
ax.set_ylim(0,8000)


# Show plot
plt.show()
# Out:
# Number of training images: 10696
# Number of validation images: 2487

# %%
# Remove empty folders and unused files

def remove_if_exists(path):
    if (os.path.isfile(path)):
        os.remove(path)


remove_if_exists(f"{dataset_path}/trainval.txt")
remove_if_exists(f"{dataset_path}/train.txt")
remove_if_exists(f"{dataset_path}/val.txt")
remove_if_exists(f"{dataset_path}/test.txt")

remove_if_exists(f"{dataset_path}/train/train.json")
remove_if_exists(f"{dataset_path}/val/val.json")
remove_if_exists(f"{dataset_path}/test/test.json")

# %% [markdown]
# ## Lastly, delete the background folder, test, train, val manually

# %% [markdown]
# Finally some more qualitative checks

# %%
import cv2

def draw_yolo_bboxes(image_path, label_path):
    # Load the image
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    with open(label_path, 'rt') as f:
        data_lines = f.readlines()
    
    bboxes = []
    w, h = 1920, 1080

    for item in range(len(data_lines)):
        cl=int(data_lines[item].split(" ")[0])
        a=float(data_lines[item].split(" ")[1])
        b=float(data_lines[item].split(" ")[2])
        c=float(data_lines[item].split(" ")[3])
        d=float(data_lines[item].split(" ")[4][:-1])
        
        x1 = int((a-c/2)*w)
        y1 = int((b-d/2)*h)
        x2 = int((a+c/2)*w)
        y2 = int((b+d/2)*h)
        
        bboxes.append([x1,y1,x2,y2,cl])

    for c in bboxes:
        cv2.rectangle(img, (c[0],c[1]), (c[2], c[3]), (0, 255, 0), 5)
        cv2.putText(img, str(id2cls[c[4]]), (int((c[0]+c[2])/2), int((c[1]+c[3])/2)), 0, 1, (255, 255, 255),3)
        
    plt.figure(figsize=(10, 6))  # Set figure size
    plt.imshow(img)
    plt.axis("off")  # Hide axes
    plt.show()

# Example usage
img_path = random.sample(glob.glob(f"{dataset_path}/images/train/*.jpg"), 1)[0]
image_name = os.path.basename(img_path)[:-4]
label_path = f"{dataset_path}/labels/train/{image_name}.txt"

draw_yolo_bboxes(img_path, label_path)
