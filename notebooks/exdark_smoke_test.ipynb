# %%
import random
import glob
import os

from utils import draw_yolo_bboxes

dataset_path = "../../yolo-testing/datasets/exDark-yolo"

id2cls_int = {
    0: "Bicycle",
    1: "Boat",
    2: "Bottle",
    3: "Bus",
    4: "Car",
    5: "Cat",
    6: "Chair",
    7: "Cup",
    8: "Dog",
    9: "Motorbike",
    10: "People",
    11: "Table"
}

# Example usage
img_path = random.sample(glob.glob(f"{dataset_path}/images/train/*.jpg"), 1)[0]
image_name = os.path.basename(img_path)[:-4]
label_path = f"{dataset_path}/labels/train/{image_name}.txt"

print(img_path, label_path)
draw_yolo_bboxes(img_path, label_path, w=500, h=375, id2cls=id2cls_int,text_size=0.5, text_thickness=2)
# Out:
# ../../yolo-testing/datasets/exDark-yolo/images/train/2015_03137.jpg ../../yolo-testing/datasets/exDark-yolo/labels/train/2015_03137.txt
